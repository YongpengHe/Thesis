# %% [markdown]
# # Transformers, what can they do?

# %% [markdown]
# Install the Transformers, Datasets, and Evaluate libraries to run this notebook.

# %%
import os
for dirname, _, filenames in os.walk('/'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# Streaming output truncated to the last 5000 lines.
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_rpo.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_posix_util.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_compose.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_setmeta.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_web.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_retention.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_autoclass.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/mock_cloud_api.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_resumable_streaming.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_creds_config.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_hashing_helper.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_signurl.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_psc.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_notification_pubsub.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_cors.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_cat.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_context_config.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_parallelism_framework.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_storage_url.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_retention_util.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_parallel_cp.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_kms.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_ui.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_plurality_checkable_iterator.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_gcs_json_media.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_label.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_Doption.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_gcs_json_credentials.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_rewrite.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_wrapped_credentials.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/mock_logging_handler.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_cp.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_lifecycle.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_help.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_cloud_api_delegator.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_bucketpolicyonly.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_gcs_json_api.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_mb.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_stet_util.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_pap.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_mtls.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_hash.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_acl.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_bucketconfig.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_iam.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_command.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_versioning.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_mv.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_execution_util.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_seek_ahead_thread.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_stet_cp.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_wildcard_iterator.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_hmac.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_rm.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_ubla.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_naming.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_tabcomplete.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_metrics.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_rb.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/signurl_signatures.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_rsync_funcs.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_boto_util.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_ls.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_tracker_file.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_update.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_logging.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_stat.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_user_agent_helper.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_shim_util.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_copy_objects_iterator.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_notification.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_encryption_helper.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_requester_pays.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_copy_helper_funcs.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_gsutil.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_perfdiag.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_trace.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_util.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_du.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_temporary_file_util.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_defacl.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_rsync.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_defstorageclass.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_file_part.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_data/test.txt
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_data/test_external_account_credentials.json
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_data/test.p12
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_data/test.mp3
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_data/test.gif
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_data/test.json
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_data/test_external_account_authorized_user_credentials.json
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/test_data/favicon.ico.gz
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/testcase/integration_testcase.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/testcase/base.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/testcase/shim_unit_test_base.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/testcase/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/testcase/unit_testcase.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/testcase/__pycache__/base.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/testcase/__pycache__/__init__.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/testcase/__pycache__/integration_testcase.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/testcase/__pycache__/unit_testcase.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/testcase/__pycache__/shim_unit_test_base.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_web.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_compose.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_encryption_helper.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/mock_cloud_api.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_kms.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_daisy_chain_wrapper.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_help.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_creds_config.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/signurl_signatures.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_versioning.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_file_part.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_context_config.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_ubla.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_update.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_gsutil.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_stet_util.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_metrics.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_rb.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_shim_util.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_defstorageclass.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_mtls.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_storage_url.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/__init__.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/util.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_naming.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_label.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_wrapped_credentials.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_command.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_gcs_json_api.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/rewrite_helper.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_rsync.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_plurality_checkable_iterator.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_cat.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_pap.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_rpo.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_psc.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_stat.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_signurl.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_bucketconfig.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_tabcomplete.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_defacl.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_hash.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_du.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_notification_pubsub.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/mock_logging_handler.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_posix_util.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_iam.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_copy_objects_iterator.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_rsync_funcs.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_hashing_helper.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_requester_pays.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_acl.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_tracker_file.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_trace.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_wildcard_iterator.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_mb.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_lifecycle.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_execution_util.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_cp.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_gcs_json_media.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_copy_helper_funcs.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_mv.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_util.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_autoclass.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_command_runner.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_retention.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_seek_ahead_thread.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_setmeta.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_parallelism_framework.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_user_agent_helper.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_cloud_api_delegator.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_gcs_json_credentials.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_rm.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_retention_util.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_cors.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_ui.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_ls.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_temporary_file_util.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_boto_util.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_notification.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_resumable_streaming.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_bucketpolicyonly.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_rewrite.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_hmac.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_logging.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_parallel_cp.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_perfdiag.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_Doption.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/tests/__pycache__/test_stet_cp.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/data/cacerts.txt
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/CHANGELOG.md
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/.travis.yml
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/.coveragerc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/Makefile
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/setup.cfg
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/CONTRIBUTING.md
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/setup.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/.gitignore
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/MANIFEST.in
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/CODE_OF_CONDUCT.md
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/LICENSE
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/tox.ini
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/README.md
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/CONTRIBUTORS.md
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/service_account.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/_openssl_crypt.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/file.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/transport.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/crypt.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/_pycrypto_crypt.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/client.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/_pkce.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/_pure_python_crypt.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/clientsecrets.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/_helpers.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/tools.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/__pycache__/_openssl_crypt.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/__pycache__/service_account.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/__pycache__/file.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/__pycache__/_pycrypto_crypt.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/__pycache__/__init__.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/__pycache__/_pkce.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/__pycache__/client.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/__pycache__/clientsecrets.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/__pycache__/crypt.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/__pycache__/_helpers.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/__pycache__/transport.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/__pycache__/_pure_python_crypt.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/__pycache__/tools.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/_metadata.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/flask_util.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/multiprocess_file_storage.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/sqlalchemy.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/appengine.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/dictionary_storage.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/keyring_storage.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/xsrfutil.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/gce.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/devshell.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/_appengine_ndb.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/__pycache__/appengine.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/__pycache__/devshell.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/__pycache__/xsrfutil.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/__pycache__/gce.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/__pycache__/__init__.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/__pycache__/flask_util.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/__pycache__/dictionary_storage.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/__pycache__/multiprocess_file_storage.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/__pycache__/_metadata.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/__pycache__/sqlalchemy.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/__pycache__/_appengine_ndb.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/__pycache__/keyring_storage.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/django_util/signals.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/django_util/views.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/django_util/decorators.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/django_util/apps.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/django_util/site.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/django_util/storage.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/django_util/models.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/django_util/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/django_util/__pycache__/views.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/django_util/__pycache__/__init__.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/django_util/__pycache__/decorators.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/django_util/__pycache__/apps.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/django_util/__pycache__/models.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/django_util/__pycache__/site.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/django_util/__pycache__/storage.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/oauth2client/contrib/django_util/__pycache__/signals.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/samples/oauth2_for_devices.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/samples/call_compute_service.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/samples/__pycache__/oauth2_for_devices.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/samples/__pycache__/call_compute_service.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/samples/googleappengine/app.yaml
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/samples/googleappengine/call_compute_service_from_gae.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/scripts/run_system_tests.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/scripts/run.sh
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/scripts/build_docs.sh
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/scripts/run_gce_system_tests.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/scripts/run_system_tests.sh
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/scripts/local_test_setup.sample
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/scripts/install.sh
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/scripts/__pycache__/run_system_tests.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/scripts/__pycache__/run_gce_system_tests.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/Makefile
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/index.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/conf.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/requirements.txt
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/_static/google_logo.png
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/_static/favicon.ico
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.contrib.devshell.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.client.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.contrib.django_util.decorators.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.contrib.django_util.views.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.contrib.django_util.signals.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.service_account.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.contrib.sqlalchemy.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.contrib.dictionary_storage.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.clientsecrets.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.contrib.django_util.site.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.tools.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.contrib.django_util.models.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.transport.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.contrib.flask_util.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.contrib.django_util.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.contrib.django_util.storage.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.contrib.appengine.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.contrib.gce.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.contrib.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.contrib.django_util.apps.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.file.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.contrib.multiprocess_file_storage.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.contrib.keyring_storage.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.crypt.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/source/oauth2client.contrib.xsrfutil.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/docs/__pycache__/conf.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/.github/ISSUE_TEMPLATE.md
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/.github/PULL_REQUEST_TEMPLATE.md
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/oauth2client/__pycache__/setup.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/requirements-docs.txt
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/.travis.yml
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/setup.cfg
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/CONTRIBUTING
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/setup.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/.gitignore
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/MANIFEST.in
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/pylintrc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/README.rst
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/LICENSE
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/requirements.txt
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/tox.ini
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/requirements-py33.txt
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/https_connection.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/utils.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/plugin.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/jsonresponse.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/endpoints.json
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/auth.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/compat.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/handler.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/exception.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/provider.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/auth_handler.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/requestlog.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/storage_uri.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/resultset.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/endpoints.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/regioninfo.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/connection.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/beanstalk/response.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/beanstalk/wrapper.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/beanstalk/layer1.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/beanstalk/exception.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/beanstalk/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/beanstalk/__pycache__/wrapper.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/beanstalk/__pycache__/response.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/beanstalk/__pycache__/exception.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/beanstalk/__pycache__/__init__.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/beanstalk/__pycache__/layer1.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/glacier/job.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/glacier/utils.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/glacier/concurrent.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/glacier/layer2.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/glacier/exceptions.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/glacier/response.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/glacier/layer1.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/glacier/vault.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/glacier/writer.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/glacier/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/glacier/__pycache__/layer2.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/glacier/__pycache__/writer.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/glacier/__pycache__/exceptions.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/glacier/__pycache__/response.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/glacier/__pycache__/__init__.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/glacier/__pycache__/job.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/glacier/__pycache__/utils.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/glacier/__pycache__/layer1.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/glacier/__pycache__/concurrent.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/glacier/__pycache__/vault.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/kinesis/exceptions.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/kinesis/layer1.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/kinesis/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/kinesis/__pycache__/exceptions.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/kinesis/__pycache__/__init__.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/kinesis/__pycache__/layer1.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/elasticache/layer1.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/elasticache/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/elasticache/__pycache__/__init__.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/elasticache/__pycache__/layer1.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudsearch/layer2.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudsearch/layer1.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudsearch/domain.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudsearch/search.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudsearch/document.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudsearch/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudsearch/sourceattribute.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudsearch/optionstatus.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudsearch/__pycache__/search.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudsearch/__pycache__/layer2.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudsearch/__pycache__/document.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudsearch/__pycache__/sourceattribute.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudsearch/__pycache__/__init__.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudsearch/__pycache__/optionstatus.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudsearch/__pycache__/domain.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudsearch/__pycache__/layer1.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/queryresultset.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/domain.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/regioninfo.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/item.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/connection.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/__pycache__/connection.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/__pycache__/queryresultset.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/__pycache__/__init__.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/__pycache__/regioninfo.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/__pycache__/domain.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/__pycache__/item.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/key.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/sequence.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/query.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/model.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/test_db.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/property.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/blob.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/manager/xmlmanager.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/manager/sdbmanager.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/manager/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/manager/__pycache__/__init__.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/manager/__pycache__/xmlmanager.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/manager/__pycache__/sdbmanager.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/__pycache__/key.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/__pycache__/sequence.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/__pycache__/__init__.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/__pycache__/model.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/__pycache__/blob.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/__pycache__/property.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/__pycache__/test_db.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sdb/db/__pycache__/query.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sqs/bigmessage.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sqs/queue.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sqs/attributes.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sqs/messageattributes.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sqs/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sqs/message.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sqs/batchresults.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sqs/regioninfo.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sqs/connection.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sqs/jsonmessage.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sqs/__pycache__/connection.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sqs/__pycache__/messageattributes.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sqs/__pycache__/__init__.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sqs/__pycache__/batchresults.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sqs/__pycache__/regioninfo.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sqs/__pycache__/queue.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sqs/__pycache__/bigmessage.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sqs/__pycache__/message.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sqs/__pycache__/attributes.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/sqs/__pycache__/jsonmessage.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/datapipeline/exceptions.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/datapipeline/layer1.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/datapipeline/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/datapipeline/__pycache__/exceptions.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/datapipeline/__pycache__/__init__.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/datapipeline/__pycache__/layer1.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/roboto/param.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/roboto/awsqueryrequest.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/roboto/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/roboto/awsqueryservice.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/roboto/__pycache__/__init__.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/roboto/__pycache__/awsqueryservice.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/roboto/__pycache__/awsqueryrequest.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/roboto/__pycache__/param.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudformation/stack.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudformation/template.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudformation/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudformation/connection.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudformation/__pycache__/connection.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudformation/__pycache__/template.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudformation/__pycache__/__init__.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/cloudformation/__pycache__/stack.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/ses/exceptions.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/ses/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/ses/connection.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/ses/__pycache__/connection.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/ses/__pycache__/exceptions.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/ses/__pycache__/__init__.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/support/exceptions.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/support/layer1.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/support/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/support/__pycache__/exceptions.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/support/__pycache__/__init__.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/support/__pycache__/layer1.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/redshift/exceptions.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/redshift/layer1.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/redshift/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/redshift/__pycache__/exceptions.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/redshift/__pycache__/__init__.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/redshift/__pycache__/layer1.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/machinelearning/exceptions.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/machinelearning/layer1.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/machinelearning/__init__.py
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/machinelearning/__pycache__/exceptions.cpython-311.pyc
# /tools/google-cloud-sdk/platform/gsutil/gslib/vendored/boto/boto/machinelearning/__pycache__/__init__.cpython-311.pyc
# ...
# /python-apt/typehinting/apt_inst.pyi
# /python-apt/python/tag.cc
# /python-apt/python/generic.h
# /python-apt/python/pkgrecords.cc
# /python-apt/python/orderlist.cc
# /python-apt/python/progress.cc
# /python-apt/python/cache.cc
# /python-apt/python/pkgrecords.h
# /python-apt/python/cachegroup.cc
# /python-apt/python/python-apt-helpers.cc
# /python-apt/python/apt_instmodule.cc
# /python-apt/python/indexfile.cc
# /python-apt/python/policy.cc
# /python-apt/python/tarfile.cc
# /python-apt/python/lock.cc
# /python-apt/python/hashstringlist.cc
# /python-apt/python/arfile.cc
# /python-apt/python/configuration.cc
# /python-apt/python/acquire-item.cc
# /python-apt/python/apt_pkgmodule.h
# /python-apt/python/string.cc
# /python-apt/python/acquire.cc
# /python-apt/python/sourcelist.cc
# /python-apt/python/pkgmanager.cc
# /python-apt/python/pkgsrcrecords.cc
# /python-apt/python/hashes.cc
# /python-apt/python/progress.h
# /python-apt/python/hashstring.cc
# /python-apt/python/depcache.cc
# /python-apt/python/apt_pkgmodule.cc
# /python-apt/python/cdrom.cc
# /python-apt/python/python-apt.h
# /python-apt/python/metaindex.cc
# /python-apt/python/apt_instmodule.h
# /python-apt/python/generic.cc
# /python-apt/doc/client-example.cc
# /python-apt/doc/Makefile
# /python-apt/doc/examples/update.py
# /python-apt/doc/examples/indexfile.py
# /python-apt/doc/examples/progress.py
# /python-apt/doc/examples/print_uris.py
# /python-apt/doc/examples/deb_inspect.py
# /python-apt/doc/examples/cdrom.py
# /python-apt/doc/examples/configisc.py
# /python-apt/doc/examples/config.py
# /python-apt/doc/examples/sources.py
# /python-apt/doc/examples/depcache.py
# /python-apt/doc/examples/checkstate.py
# /python-apt/doc/examples/build-deps-old.py
# /python-apt/doc/examples/acquire.py
# /python-apt/doc/examples/desc.py
# /python-apt/doc/examples/records.py
# /python-apt/doc/examples/architecture.py
# /python-apt/doc/examples/all_deps.py
# /python-apt/doc/examples/build-deps.py
# /python-apt/doc/examples/recommends.py
# /python-apt/doc/examples/dependant-pkgs.py
# /python-apt/doc/examples/versiontest.py
# /python-apt/doc/examples/tagfile.py
# /python-apt/doc/examples/metaindex.py
# /python-apt/doc/examples/action.py
# /python-apt/doc/examples/inst.py
# /python-apt/doc/source/contents.rst
# /python-apt/doc/source/conf.py
# /python-apt/doc/source/c++/index.rst
# /python-apt/doc/source/c++/api.rst
# /python-apt/doc/source/c++/embedding.rst
# /python-apt/doc/source/templates/indexcontent.html
# /python-apt/doc/source/templates/layout.html
# /python-apt/doc/source/examples/cache-pkgfile.py
# /python-apt/doc/source/examples/dpkg-info.py
# /python-apt/doc/source/examples/update-print-uris.py
# /python-apt/doc/source/examples/apt-cdrom.py
# /python-apt/doc/source/examples/cache-packages.py
# /python-apt/doc/source/examples/missing-deps.py
# /python-apt/doc/source/examples/dpkg-extract.py
# /python-apt/doc/source/examples/dpkg-contents.py
# /python-apt/doc/source/whatsnew/0.8.0.rst
# /python-apt/doc/source/whatsnew/1.4.rst
# /python-apt/doc/source/whatsnew/0.7.100.rst
# /python-apt/doc/source/whatsnew/1.1.rst
# /python-apt/doc/source/whatsnew/2.0.rst
# /python-apt/doc/source/whatsnew/2.1.rst
# /python-apt/doc/source/whatsnew/1.0.rst
# /python-apt/doc/source/whatsnew/index.rst
# /python-apt/doc/source/whatsnew/1.6.rst
# /python-apt/doc/source/whatsnew/0.9.4.rst
# /python-apt/doc/source/whatsnew/1.8.rst
# /python-apt/doc/source/whatsnew/1.7.rst
# /python-apt/doc/source/tutorials/apt-get.rst
# /python-apt/doc/source/tutorials/index.rst
# /python-apt/doc/source/tutorials/contributing.rst
# /python-apt/doc/source/tutorials/apt-cdrom.rst
# /python-apt/doc/source/library/aptsources.distro.rst
# /python-apt/doc/source/library/apt.debfile.rst
# /python-apt/doc/source/library/apt.cdrom.rst
# /python-apt/doc/source/library/apt.progress.base.rst
# /python-apt/doc/source/library/apt_pkg.rst
# /python-apt/doc/source/library/index.rst
# /python-apt/doc/source/library/aptsources.sourceslist.rst
# /python-apt/doc/source/library/apt_inst.rst
# /python-apt/doc/source/library/apt.cache.rst
# /python-apt/doc/source/library/apt.progress.text.rst
# /python-apt/doc/source/library/apt.package.rst
# /python-apt/doc/source/library/aptsources.distinfo.rst
# /python-apt/apt/package.py
# /python-apt/apt/utils.py
# /python-apt/apt/py.typed
# /python-apt/apt/auth.py
# /python-apt/apt/cdrom.py
# /python-apt/apt/cache.py
# /python-apt/apt/__init__.py
# /python-apt/apt/debfile.py
# /python-apt/apt/progress/base.py
# /python-apt/apt/progress/__init__.py
# /python-apt/apt/progress/text.py
# /python-apt/aptsources/distro.py
# /python-apt/aptsources/sourceslist.py
# /python-apt/aptsources/distinfo.py
# /python-apt/aptsources/__init__.py
# /python-apt/tests/test_sourcerecords.py
# /python-apt/tests/test_hashes.py
# /python-apt/tests/test_lp659438.py
# /python-apt/tests/test_debfile_multiarch.py
# /python-apt/tests/test_group.py
# /python-apt/tests/test_pep484.py
# /python-apt/tests/fakeroot-apt-key
# /python-apt/tests/testcommon.py
# /python-apt/tests/test_cve_2020_27351.py
# /python-apt/tests/test_apt_cache.py
# /python-apt/tests/test_lfs.py
# /python-apt/tests/test_auth.py
# /python-apt/tests/test_paths.py
# /python-apt/tests/test_cache_invocation.py
# /python-apt/tests/test_install_progress_exec.py
# /python-apt/tests/testmanual_pycodestyle.py
# /python-apt/tests/test_pyflakes.py
# /python-apt/tests/test_utils.py
# /python-apt/tests/test_aptsources_ports.py
# /python-apt/tests/__init__.py
# /python-apt/tests/test_size_to_str.py
# /python-apt/tests/test_tagfile.py
# /python-apt/tests/test_hashsums.py
# /python-apt/tests/test_aptsources.py
# /python-apt/tests/test_signed_usable.py
# /python-apt/tests/test_progress.py
# /python-apt/tests/test_large_file.py
# /python-apt/tests/test_deps.py
# /python-apt/tests/test_policy.py
# /python-apt/tests/test_configuration.py
# /python-apt/tests/test_debfile.py
# /python-apt/tests/helper_install_progress_run.py
# /python-apt/tests/test_all.py
# /python-apt/tests/data/test_debs/hello_2.5-1.dsc
# /python-apt/tests/data/test_debs/gdebi-test6.deb
# /python-apt/tests/data/test_debs/data-tar-broken.deb
# /python-apt/tests/data/test_debs/gdebi-test2.deb
# /python-apt/tests/data/test_debs/large-package-content_1.0_all.deb
# /python-apt/tests/data/test_debs/gdebi-test13.deb
# /python-apt/tests/data/test_debs/gdebi-test4.deb
# /python-apt/tests/data/test_debs/data-tar.deb
# /python-apt/tests/data/test_debs/data-tar-xz.deb
# /python-apt/tests/data/test_debs/utf8-package_1.0-1_all.deb
# /python-apt/tests/data/test_debs/gdebi-test1.deb
# /python-apt/tests/data/test_debs/impossible-build-depends_2.5-1.dsc
# /python-apt/tests/data/test_debs/gdebi-test10.deb
# /python-apt/tests/data/test_debs/testdep-same-arch_1.0-1_i386.deb
# /python-apt/tests/data/test_debs/gdebi-test11.deb
# /python-apt/tests/data/test_debs/gdebi-test9.deb
# /python-apt/tests/data/test_debs/gdebi-test7.deb
# /python-apt/tests/data/test_debs/gdebi-test3.deb
# /python-apt/tests/data/test_debs/testdep-allowed-any_1.0-1_i386.deb
# /python-apt/tests/data/test_debs/multiarch-test1_i386.deb
# /python-apt/tests/data/test_debs/gdebi-test8.deb
# /python-apt/tests/data/test_debs/gdebi-test5.deb
# /python-apt/tests/data/test_debs/gdebi-test12.deb
# /python-apt/tests/data/test_debs/var/lib/apt/lists/archive.ubuntu.com_ubuntu_dists_maverick_main_binary-i386_Packages
# /python-apt/tests/data/test_debs/var/lib/dpkg/status
# /python-apt/tests/data/test_debs/etc/apt/sources.list
# /python-apt/tests/data/aptsources/os-release
# /python-apt/tests/data/aptsources/sources.list.testDistribution
# /python-apt/tests/data/aptsources/sources.list.testDuplication
# /python-apt/tests/data/aptsources/sources.list
# /python-apt/tests/data/aptsources/lsb-release
# /python-apt/tests/data/test-signed-usable-repo/key.gpg.base64
# /python-apt/tests/data/test-signed-usable-repo/seckey.asc
# /python-apt/tests/data/test-signed-usable-repo/unsigned/unsigned-unusable_1.0_all.deb
# /python-apt/tests/data/test-signed-usable-repo/unsigned/unsigned-not-usable_1.0.dsc
# /python-apt/tests/data/test-signed-usable-repo/unsigned/unsigned-usable_1.0_all.deb
# /python-apt/tests/data/test-signed-usable-repo/unsigned/Release
# /python-apt/tests/data/test-signed-usable-repo/unsigned/unsigned-usable_1.0.dsc
# /python-apt/tests/data/test-signed-usable-repo/unsigned/Packages
# /python-apt/tests/data/test-signed-usable-repo/unsigned/Sources
# /python-apt/tests/data/test-signed-usable-repo/signed/signed-usable_1.0.dsc
# /python-apt/tests/data/test-signed-usable-repo/signed/signed-not-usable_1.0_all.deb
# /python-apt/tests/data/test-signed-usable-repo/signed/signed-not-usable_1.0.dsc
# /python-apt/tests/data/test-signed-usable-repo/signed/Release.gpg
# /python-apt/tests/data/test-signed-usable-repo/signed/Release
# /python-apt/tests/data/test-signed-usable-repo/signed/Packages
# /python-apt/tests/data/test-signed-usable-repo/signed/signed-usable_1.0_all.deb
# /python-apt/tests/data/test-signed-usable-repo/signed/Sources
# /python-apt/tests/data/test-repo/Packages.gz
# /python-apt/tests/data/misc/foo_Release
# /python-apt/tests/data/hashsums/hashsum_test_with_zero.data
# /python-apt/tests/data/hashsums/hashsum_test.data
# /python-apt/tests/data/test-provides/var/lib/apt/lists/archive.ubuntu.com_ubuntu_dists_oneiric_main_binary-i386_Packages
# /python-apt/tests/data/test-provides/var/lib/dpkg/status
# /python-apt/tests/data/test-provides/etc/apt/sources.list
# /python-apt/tests/data/tagfile/history.log
# /python-apt/tests/data/tagfile/history.1.log.gz
# /python-apt/tests/data/aptsources_ports/sources.list
# /python-apt/tests/data/test-source-repo/Sources
# /python-apt/tests/data/test-repo2/Packages.gz
# /python-apt/tests/data/fake-packages/Packages.gz
# /python-apt/tests/data/fake-packages/Packages
# /python-apt/tests/old/memleak.py
# /python-apt/tests/old/test_enhances.py
# /python-apt/tests/old/refcount.py
# /python-apt/tests/old/apt-test.py
# /python-apt/tests/old/depcache.py
# /python-apt/tests/old/pkgproblemresolver.py
# /python-apt/tests/old/pkgsrcrecords.py
# /python-apt/tests/old/pkgrecords.py
# /python-apt/tests/old/cache.py
# /python-apt/tests/old/__init__.py
# /python-apt/tests/old/lock.py
# /python-apt/data/templates/README.templates
# /python-apt/data/templates/Blankon.info.in
# /python-apt/data/templates/Tanglu.mirrors
# /python-apt/data/templates/Blankon.mirrors
# /python-apt/data/templates/gNewSense.info.in
# /python-apt/data/templates/Tanglu.info.in
# /python-apt/data/templates/Kali.mirrors
# /python-apt/data/templates/Kali.info.in
# /python-apt/data/templates/Ubuntu.info.in
# /python-apt/data/templates/Debian.info.in
# /python-apt/data/templates/Ubuntu.mirrors
# /python-apt/data/templates/gNewSense.mirrors
# /python-apt/data/templates/Debian.mirrors
# /python-apt/debian/python-apt-doc.maintscript
# /python-apt/debian/gbp.conf
# /python-apt/debian/copyright
# /python-apt/debian/python-apt-dev.maintscript
# /python-apt/debian/rules
# /python-apt/debian/changelog
# /python-apt/debian/python-apt-doc.docs
# /python-apt/debian/python-apt-doc.doc-base
# /python-apt/debian/python-apt-doc.examples
# /python-apt/debian/control
# /python-apt/debian/python-apt-dev.install
# /python-apt/debian/python3-apt.lintian-overrides
# /python-apt/debian/python-apt-dev.examples
# /python-apt/debian/tests/run-tests
# /python-apt/debian/tests/control
# /python-apt/debian/source/format
# /python-apt/po/sl.po
# /python-apt/po/zh_CN.po
# /python-apt/po/csb.po
# /python-apt/po/zh_TW.po
# /python-apt/po/vi.po
# /python-apt/po/gl.po
# /python-apt/po/pt_BR.po
# /python-apt/po/ar.po
# /python-apt/po/be.po
# /python-apt/po/tl.po
# /python-apt/po/POTFILES.in
# /python-apt/po/fr.po
# /python-apt/po/pl.po
# /python-apt/po/da.po
# /python-apt/po/ka.po
# /python-apt/po/sv.po
# /python-apt/po/ca.po
# /python-apt/po/tr.po
# /python-apt/po/hu.po
# /python-apt/po/lv.po
# /python-apt/po/el.po
# /python-apt/po/nl.po
# /python-apt/po/th.po
# /python-apt/po/de.po
# /python-apt/po/lt.po
# /python-apt/po/bg.po
# /python-apt/po/en_CA.po
# /python-apt/po/sk.po
# /python-apt/po/ku.po
# /python-apt/po/python-apt.pot
# /python-apt/po/mk.po
# /python-apt/po/cs.po
# /python-apt/po/nb.po
# /python-apt/po/ro.po
# /python-apt/po/es.po
# /python-apt/po/ko.po
# /python-apt/po/he.po
# /python-apt/po/sr.po
# /python-apt/po/fi.po
# /python-apt/po/pt.po
# /python-apt/po/id.po
# /python-apt/po/uk.po
# /python-apt/po/it.po
# /python-apt/po/ru.po
# /python-apt/po/bn.po
# /python-apt/po/zh_HK.po
# /python-apt/po/oc.po
# /python-apt/po/ja.po
# /python-apt/po/eo.po
# /python-apt/po/hr.po
# /python-apt/po/ne.po
# /python-apt/po/en_AU.po
# /python-apt/po/sq.po
# /python-apt/python_apt.egg-info/PKG-INFO
# /python-apt/python_apt.egg-info/top_level.txt
# /python-apt/python_apt.egg-info/dependency_links.txt
# /python-apt/python_apt.egg-info/SOURCES.txt
# /python-apt/build/data/templates/Ubuntu.info
# /python-apt/build/data/templates/Blankon.info
# /python-apt/build/data/templates/Tanglu.mirrors
# /python-apt/build/data/templates/Blankon.mirrors
# /python-apt/build/data/templates/Kali.mirrors
# /python-apt/build/data/templates/Kali.info
# /python-apt/build/data/templates/gNewSense.info
# /python-apt/build/data/templates/Ubuntu.mirrors
# /python-apt/build/data/templates/gNewSense.mirrors
# /python-apt/build/data/templates/Debian.info
# /python-apt/build/data/templates/Tanglu.info
# /python-apt/build/data/templates/Debian.mirrors
# /python-apt/build/temp.linux-x86_64-cpython-311/python/depcache.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/configuration.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/policy.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/generic.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/progress.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/lock.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/cachegroup.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/pkgmanager.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/tarfile.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/apt_pkgmodule.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/cdrom.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/pkgsrcrecords.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/cache.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/hashes.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/string.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/orderlist.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/hashstring.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/sourcelist.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/hashstringlist.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/acquire-item.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/metaindex.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/pkgrecords.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/acquire.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/arfile.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/apt_instmodule.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/python-apt-helpers.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/tag.o
# /python-apt/build/temp.linux-x86_64-cpython-311/python/indexfile.o
# /python-apt/build/lib.linux-x86_64-cpython-311/apt_pkg.cpython-311-x86_64-linux-gnu.so
# /python-apt/build/lib.linux-x86_64-cpython-311/apt_inst.cpython-311-x86_64-linux-gnu.so
# /python-apt/build/lib.linux-x86_64-cpython-311/apt/package.py
# /python-apt/build/lib.linux-x86_64-cpython-311/apt/utils.py
# /python-apt/build/lib.linux-x86_64-cpython-311/apt/py.typed
# /python-apt/build/lib.linux-x86_64-cpython-311/apt/auth.py
# /python-apt/build/lib.linux-x86_64-cpython-311/apt/cdrom.py
# /python-apt/build/lib.linux-x86_64-cpython-311/apt/cache.py
# /python-apt/build/lib.linux-x86_64-cpython-311/apt/__init__.py
# /python-apt/build/lib.linux-x86_64-cpython-311/apt/debfile.py
# /python-apt/build/lib.linux-x86_64-cpython-311/apt/progress/base.py
# /python-apt/build/lib.linux-x86_64-cpython-311/apt/progress/__init__.py
# /python-apt/build/lib.linux-x86_64-cpython-311/apt/progress/text.py
# /python-apt/build/lib.linux-x86_64-cpython-311/aptsources/distro.py
# /python-apt/build/lib.linux-x86_64-cpython-311/aptsources/sourceslist.py
# /python-apt/build/lib.linux-x86_64-cpython-311/aptsources/distinfo.py
# /python-apt/build/lib.linux-x86_64-cpython-311/aptsources/__init__.py
# /python-apt/utils/get_debian_mirrors.py
# /python-apt/utils/mirrortest
# /python-apt/utils/get_ubuntu_mirrors_from_lp.py
# /python-apt/utils/expand_info.py

# %%
# !pip install datasets evaluate transformers[sentencepiece]
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (2.14.4)
# Collecting evaluate
#   Downloading evaluate-0.4.3-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: transformers[sentencepiece] in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec>=2021.11.1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2021.11.1->datasets) (2025.3.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.14.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.31.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers[sentencepiece]) (3.18.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers[sentencepiece]) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers[sentencepiece]) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers[sentencepiece]) (0.5.3)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in /usr/local/lib/python3.11/dist-packages (from transformers[sentencepiece]) (0.2.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from transformers[sentencepiece]) (5.29.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.14.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading evaluate-0.4.3-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 1.3 MB/s eta 0:00:00
# Installing collected packages: evaluate
# Successfully installed evaluate-0.4.3

# %%
from transformers import pipeline

classifier = pipeline("sentiment-analysis")
classifier("I've been waiting for a HuggingFace course my whole life.")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Device set to use cpu
# [{'label': 'POSITIVE', 'score': 0.9598049521446228}]

# %%
classifier(
    ["I've been waiting for a HuggingFace course my whole life.", "I hate this so much!"]
)
# Out:
# [{'label': 'POSITIVE', 'score': 0.9598049521446228},
#  {'label': 'NEGATIVE', 'score': 0.9994558691978455}]

# %%
from transformers import pipeline

classifier = pipeline("zero-shot-classification")
classifier(
    "This is a course about the Transformers library",
    candidate_labels=["education", "politics", "business"],
)
# Out:
# {'sequence': 'This is a course about the Transformers library',
#  'labels': ['education', 'business', 'politics'],
#  'scores': [0.8445963859558105, 0.111976258456707, 0.043427448719739914]}

# %%
from transformers import pipeline

# Initialize the image-to-text pipeline
# You might need to specify a model for this task, for example "nlpconnect/vit-gpt2-image-captioning"
image_to_text = pipeline("image-to-text", model="nlpconnect/vit-gpt2-image-captioning")

# You would then use this pipeline with an image file.
# For example:
result = image_to_text("/content/Cantilever-Bridge-1024x568.jpg")
print(result)

# As an example, here's a placeholder call.
# You'll need to provide an actual image path.
# print("Please provide the path to your image file to run image-to-text.")
# Out:
# Config of the encoder: <class 'transformers.models.vit.modeling_vit.ViTModel'> is overwritten by shared encoder config: ViTConfig {
#   "architectures": [
#     "ViTModel"
#   ],
#   "attention_probs_dropout_prob": 0.0,
#   "encoder_stride": 16,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.0,
#   "hidden_size": 768,
#   "image_size": 224,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-12,
#   "model_type": "vit",
#   "num_attention_heads": 12,
#   "num_channels": 3,
#   "num_hidden_layers": 12,
#   "patch_size": 16,
#   "pooler_act": "tanh",
#   "pooler_output_size": 768,
#   "qkv_bias": true,
#   "torch_dtype": "float32",
#   "transformers_version": "4.51.3"
# }
#
# Config of the decoder: <class 'transformers.models.gpt2.modeling_gpt2.GPT2LMHeadModel'> is overwritten by shared decoder config: GPT2Config {
#   "activation_function": "gelu_new",
#   "add_cross_attention": true,
#   "architectures": [
#     "GPT2LMHeadModel"
#   ],
#   "attn_pdrop": 0.1,
#   "bos_token_id": 50256,
#   "decoder_start_token_id": 50256,
#   "embd_pdrop": 0.1,
#   "eos_token_id": 50256,
#   "initializer_range": 0.02,
#   "is_decoder": true,
#   "layer_norm_epsilon": 1e-05,
#   "model_type": "gpt2",
#   "n_ctx": 1024,
#   "n_embd": 768,
#   "n_head": 12,
#   "n_inner": null,
#   "n_layer": 12,
#   "n_positions": 1024,
#   "pad_token_id": 50256,
#   "reorder_and_upcast_attn": false,
#   "resid_pdrop": 0.1,
#   "scale_attn_by_inverse_layer_idx": false,
#   "scale_attn_weights": true,
#   "summary_activation": null,
#   "summary_first_dropout": 0.1,
#   "summary_proj_to_labels": true,
#   "summary_type": "cls_index",
#   "summary_use_proj": true,
#   "task_specific_params": {
#     "text-generation": {
#       "do_sample": true,
#       "max_length": 50
#     }
#   },
#   "torch_dtype": "float32",
#   "transformers_version": "4.51.3",
#   "use_cache": true,
#   "vocab_size": 50257
# }
#
# Device set to use cpu
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# We strongly recommend passing in an `attention_mask` since your input_ids may be padded. See https://huggingface.co/docs/transformers/troubleshooting#incorrect-output-when-padding-tokens-arent-masked.
# You may ignore this warning if your `pad_token_id` (50256) is identical to the `bos_token_id` (50256), `eos_token_id` (50256), or the `sep_token_id` (None), and your input is not padded.
# [{'generated_text': 'a bridge over a river with a train on it '}]

# %%
from transformers import pipeline

generator = pipeline("text-generation")
generator("In this course, we will teach you how to")
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d (https://huggingface.co/openai-community/gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'In this course, we will teach you how to connect with your team and build on those positive results in your free time.\n\nOur online group will be focused on networking and you will be able to find other community members who may be interested in'}]

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="distilgpt2")
generator(
    "In this course, we will teach you how to",
    max_length=20,
    num_return_sequences=2,
)
# Out:
# Device set to use cpu
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# [{'generated_text': 'In this course, we will teach you how to use the codebase to help you make a faster'},
#  {'generated_text': 'In this course, we will teach you how to properly design a solid and solid board - or even'}]

# %%
from transformers import pipeline

unmasker = pipeline("fill-mask")
unmasker("This course will teach you all about <mask> optimization models.", top_k=2)
# Out:
# No model was supplied, defaulted to distilbert/distilroberta-base and revision fb53ab8 (https://huggingface.co/distilbert/distilroberta-base).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/480 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# WARNING:huggingface_hub.file_download:Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/331M [00:00<?, ?B/s]
# Some weights of the model checkpoint at distilbert/distilroberta-base were not used when initializing RobertaForMaskedLM: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu
# [{'score': 0.19619767367839813,
#   'token': 30412,
#   'token_str': ' mathematical',
#   'sequence': 'This course will teach you all about mathematical models.'},
#  {'score': 0.04052715748548508,
#   'token': 38163,
#   'token_str': ' computational',
#   'sequence': 'This course will teach you all about computational models.'}]

# %%
from transformers import pipeline

ner = pipeline("ner", grouped_entities=True)
ner("My name is Sylvain and I work at Hugging Face in Brooklyn.")
# Out:
# [{'entity_group': 'PER', 'score': 0.99816, 'word': 'Sylvain', 'start': 11, 'end': 18},
#  {'entity_group': 'ORG', 'score': 0.97960, 'word': 'Hugging Face', 'start': 33, 'end': 45},
#  {'entity_group': 'LOC', 'score': 0.99321, 'word': 'Brooklyn', 'start': 49, 'end': 57}
# ]

# %%
from transformers import pipeline

question_answerer = pipeline("question-answering")
question_answerer(
    question="Where do I work?",
    context="My name is Sylvain and I work at Hugging Face in Brooklyn",
)
# Out:
# {'score': 0.6385916471481323, 'start': 33, 'end': 45, 'answer': 'Hugging Face'}

# %%
from transformers import pipeline

summarizer = pipeline("summarization")
summarizer(
    """
    America has changed dramatically during recent years. Not only has the number of
    graduates in traditional engineering disciplines such as mechanical, civil,
    electrical, chemical, and aeronautical engineering declined, but in most of
    the premier American universities engineering curricula now concentrate on
    and encourage largely the study of engineering science. As a result, there
    are declining offerings in engineering subjects dealing with infrastructure,
    the environment, and related issues, and greater concentration on high
    technology subjects, largely supporting increasingly complex scientific
    developments. While the latter is important, it should not be at the expense
    of more traditional engineering.

    Rapidly developing economies such as China and India, as well as other
    industrial countries in Europe and Asia, continue to encourage and advance
    the teaching of engineering. Both China and India, respectively, graduate
    six and eight times as many traditional engineers as does the United States.
    Other industrial countries at minimum maintain their output, while America
    suffers an increasingly serious decline in the number of engineering graduates
    and a lack of well-educated engineers.
"""
)
# Out:
# [{'summary_text': ' America has changed dramatically during recent years . The '
#                   'number of engineering graduates in the U.S. has declined in '
#                   'traditional engineering disciplines such as mechanical, civil '
#                   ', electrical, chemical, and aeronautical engineering . Rapidly '
#                   'developing economies such as China and India, as well as other '
#                   'industrial countries in Europe and Asia, continue to encourage '
#                   'and advance engineering .'}]

# %%
from transformers import pipeline

translator = pipeline("translation", model="Helsinki-NLP/opus-mt-fr-en")
translator("Ce cours est produit par Hugging Face.")
# Out:
# [{'translation_text': 'This course is produced by Hugging Face.'}]
